# %% [markdown]
# # Aula 2:
#
# Foco da aula:
#   - Introdução à conteitos matemáticos e estatísticos interdisciplinares relacionados à IA e Mineração de Dados.
#   - Exercícios Práticos.
#   - Análise Exploratória de Dados (AED)
#   - Extração, Transformação e Carregamento (ETL)

# %% [markdown]
# ## Importação das Bibliotecas:
#
# - Pandas.
# - Numpy.
# - Matplotlib
# - Seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import scipy as sp
from scipy.stats import ttest_1samp
from scipy.stats import ttest_ind
from scipy.stats import ttest_rel
from scipy.stats import f_oneway
from statsmodels.stats.multicomp import pairwise_tukeyhsd
from scipy.stats import normaltest

# %% [markdown]
# ## ETL:

# %% [markdown]
# ### Iremos importar os dados que utilizaremos na aula.

# %% [markdown]
# #### Links Dados:

# %%
link_ideb = 'https://raw.githubusercontent.com/omiguelsma/unifeb-si-sistemas-inteligentes/main/BIM%201/AULA%202/DADOS/ideb.csv'

# %%
link_pib = 'https://raw.githubusercontent.com/omiguelsma/unifeb-si-sistemas-inteligentes/main/BIM%201/AULA%202/DADOS/pib.csv'

# %%
link_seg_rj = 'https://raw.githubusercontent.com/omiguelsma/unifeb-si-sistemas-inteligentes/main/BIM%201/AULA%202/DADOS/seg_rj.csv'

# %% [markdown]
# ## AED:

# %% [markdown]
# ### Seg RJ:

# %%
# Leia os dados com o pandas

# %%
# Veja o tipo de dados de cada coluna.

# %%
# Veja os dados faltantes.

# %%
# Veja as medidas de tendência central (média, moda e mediana) de 3 colunas (escolha as que quiser)

# %%
# Faça um bloxplot de 2 colunas (escolha as que quiser)

# %% [markdown]
# ### PIB:

# %%
# Leia os dados com o pandas

# %%
# Veja o tipo de dados de cada coluna.

# %%
# Se precisar, transforme os dados das colunas.

# %%
# Veja as medidas de dispersão de 5 colunas (variância, desvio médio, desvio padrão e coeficiente de variação)

# %%
# Faça uma correlação entre as colunas do dataframe.

# %%
# Faça um mapa de calor de correlação com o seaborn

# %% [markdown]
# ### Ideb:

# %%
# Leia os dados com o pandas

# %%
# Veja o tipo de dados de cada coluna.

# %%
# Se precisar, transforme os dados das colunas.

# %%
# Veja o tipo de dados de cada coluna.

# %%
# Verifique se há NA's

# %%
# Se houver, exclua os dados ausentes.

# %%
# Faça uma correlação entre as colunas do dataframe.

# %%
# Com base nos dados peça ao bard para auxiliá-lo a construir um teste de hipótese simples.
