# %% [markdown]
# # Aula 2:
#
# Foco da aula:
#   - Introdução à conteitos matemáticos e estatísticos interdisciplinares relacionados à IA e Mineração de Dados.
#   - Exercícios Práticos.
#   - Análise Exploratória de Dados (AED)
#   - Extração, Transformação e Carregamento (ETL)

# %% [markdown]
# ## Importação das Bibliotecas:
#
# - Pandas.
# - Numpy.
# - Matplotlib
# - Seaborn

# %% [markdown]
# ## ETL:

# %% [markdown]
# ### Iremos importar os dados que utilizaremos na aula.

# %% [markdown]
# #### Links Dados:

# %%
link_ideb = 'https://raw.githubusercontent.com/omiguelsma/unifeb-si-sistemas-inteligentes/main/BIM%201/AULA%202/DADOS/ideb.csv'

# %%
link_pib = 'https://raw.githubusercontent.com/omiguelsma/unifeb-si-sistemas-inteligentes/main/BIM%201/AULA%202/DADOS/pib.csv'

# %% [markdown]
# ## AED:

# %% [markdown]
# ### Ideb:

# %% [markdown]
# ### PIB:
